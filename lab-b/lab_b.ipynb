# %% [markdown]
# # Lab B template code

# %%
# Get user input. Do not edit this cell
height = input('Enter cylinder height in meters')

# %%
# Solution code - Enter your code here
print("Hello. My email address is:")
print("ziqi.zhao-5@student.manchester.ac.uk")

try:
    h = float(height)*15.205
    print(h)
except:
    print("Input number type error.")
# Out:
# Hello. My email address is:
# ziqi.zhao-5@student.manchester.ac.uk
# 15.205
